# %% [markdown]
# <a href="https://colab.research.google.com/github/Dm2998/Data_Analysis_Lab_A/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
proj = pd.read_csv('dataProj.csv')

# %%
proj.head
# Out:
# <bound method NDFrame.head of           dateRep  day  month  year    cases  deaths Countries geoId  \
# 0      23/10/2022   23     10  2022   3557.0     0.0   Austria    AT
# 1      22/10/2022   22     10  2022   5494.0     4.0   Austria    AT
# 2      21/10/2022   21     10  2022   7776.0     4.0   Austria    AT
# 3      20/10/2022   20     10  2022   8221.0     6.0   Austria    AT
# 4      19/10/2022   19     10  2022  10007.0     8.0   Austria    AT
# ...           ...  ...    ...   ...      ...     ...       ...   ...
# 28724  08/02/2020    8      2  2020      0.0     0.0    Sweden    SE
# 28725  07/02/2020    7      2  2020      0.0     0.0    Sweden    SE
# 28726  06/02/2020    6      2  2020      0.0     0.0    Sweden    SE
# 28727  05/02/2020    5      2  2020      0.0     0.0    Sweden    SE
# 28728  04/02/2020    4      2  2020      1.0     0.0    Sweden    SE
#
#       countryterritoryCode  popData2020 continentExp
# 0                      AUT      8901064       Europe
# ...

# %%
proj.info
proj
# Out:
#           dateRep  day  month  year    cases  deaths Countries geoId  \
# 0      23/10/2022   23     10  2022   3557.0     0.0   Austria    AT
# 1      22/10/2022   22     10  2022   5494.0     4.0   Austria    AT
# 2      21/10/2022   21     10  2022   7776.0     4.0   Austria    AT
# 3      20/10/2022   20     10  2022   8221.0     6.0   Austria    AT
# 4      19/10/2022   19     10  2022  10007.0     8.0   Austria    AT
# ...           ...  ...    ...   ...      ...     ...       ...   ...
# 28724  08/02/2020    8      2  2020      0.0     0.0    Sweden    SE
# 28725  07/02/2020    7      2  2020      0.0     0.0    Sweden    SE
# 28726  06/02/2020    6      2  2020      0.0     0.0    Sweden    SE
# 28727  05/02/2020    5      2  2020      0.0     0.0    Sweden    SE
# 28728  04/02/2020    4      2  2020      1.0     0.0    Sweden    SE
#
#       countryterritoryCode  popData2020 continentExp
# 0                      AUT      8901064       Europe
# ...

# %%
proj["Countries"].value_counts().head(20)
# Out:
# Finland        1024
# France         1006
# Czechia        1003
# Lithuania       997
# Germany         992
# Sweden          982
# Norway          980
# Italy           974
# Estonia         973
# Luxembourg      973
# Croatia         972
# Austria         971
# Greece          971
# Latvia          970
# Hungary         968
# Belgium         968
# Netherlands     967
# Poland          966
# Slovenia        965
# Malta           964
# Name: Countries, dtype: int64

# %%
# proj['dateRep'] = proj.data.csv(proj['dateRep'], format='%d/%m/%Y')

proj.value_counts()
# Out:
# dateRep     day  month  year  cases     deaths  Countries    geoId  countryterritoryCode  popData2020  continentExp
# 01/01/2020  1    1      2020  1.0       0.0     Finland      FI     FIN                   5525292      Europe          1
# 21/03/2021  21   3      2021  6969.0    16.0    Netherlands  NL     NLD                   17407585     Europe          1
# 21/03/2022  21   3      2022  1960.0    10.0    Bulgaria     BG     BGR                   6951482      Europe          1
#                               1352.0    3.0     Latvia       LV     LVA                   1907675      Europe          1
#                               922.0     14.0    Sweden       SE     SWE                   10327589     Europe          1
#                                                                                                                       ..
# 11/02/2022  11   2      2022  5169.0    44.0    Croatia      HR     HRV                   4058165      Europe          1
# ...

# %%
daily_cases = proj.groupby('dateRep')['cases'].sum()
daily_cases
# Out:
# dateRep
# 01/01/2020         2.0
# 01/01/2021    114727.0
# 01/01/2022    594516.0
# 01/02/2020        17.0
# 01/02/2021     81015.0
#                 ...
# 31/08/2022    118731.0
# 31/10/2020    182875.0
# 31/10/2021     77074.0
# 31/12/2020    161231.0
# 31/12/2021    727028.0
# Name: cases, Length: 1030, dtype: float64

# %%
daily_cases = daily_cases.reset_index()
daily_cases
# Out:
#       index     dateRep     cases
# 0         0  01/01/2020       2.0
# 1         1  01/01/2021  114727.0
# 2         2  01/01/2022  594516.0
# 3         3  01/02/2020      17.0
# 4         4  01/02/2021   81015.0
# ...     ...         ...       ...
# 1025   1025  31/08/2022  118731.0
# 1026   1026  31/10/2020  182875.0
# 1027   1027  31/10/2021   77074.0
# 1028   1028  31/12/2020  161231.0
# 1029   1029  31/12/2021  727028.0
#
# [1030 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# daily_cases['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# daily_cases['cases'].plot(kind='hist', bins=20, title='cases')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# ...

# %%
from matplotlib import pyplot as plt
daily_cases['cases'].plot(kind='hist', bins=20, title='cases 2020')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
daily_cases['index'].plot(kind='line', figsize=(8, 4), title='index')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
proj["Countries"].max()
# Out:
# 'Sweden'

# %%
from matplotlib import pyplot as plt
proj.plot(kind='scatter', x='cases', y='deaths', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
proj['day'].plot(kind='hist', bins=20, title='day')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
proj['year'].plot(kind='hist', bins=20, title='year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
proj['cases'].plot(kind='hist', bins=20, title='cases')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['dateRep']
  ys = series['day']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = proj.sort_values('dateRep', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('dateRep')
_ = plt.ylabel('day')
